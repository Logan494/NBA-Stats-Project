# %%
# Import libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import os
import sklearn
from sklearn.cluster import KMeans # Here is where you import the k-means algorithm from scikit-learn.
import pylab as pl # PyLab is a convenience module that bulk imports matplotlib.

# %%
# Ensure the graphs are displayed in notebook

# %matplotlib inline

# %%
#creating path
path = 'C:/Users/logan/Downloads/CareerFoundry/NBA Stats'

# %%
#connecting csv
df = pd.read_csv(os.path.join(path, '02 Data',  'Prepared Data', 'final nba stats set csv position fix.csv'))

# %%
# Drop column 'collegel

df = df.drop(columns = ['college'])

# %%
#filtering out rows with net_rating above 30 or below -30
df = df[(df['net_rating'] <= 30) & (df['net_rating'] >= -30)]

# %%
#filtering out players who played less than five games
df = df[df['gp'] >= 30]

# %%
df.head()
# Out:
#    player_id  season      player team_abbreviation       state  age  \
# 0        419    1997  A.C. Green               DAL       Texas   33
# 1        667    1998  A.C. Green               DAL       Texas   34
# 2       1006    1999  A.C. Green               DAL       Texas   35
# 3       9331    2000  A.C. Green               LAL  California   36
# 4      11196    2001  A.C. Green               MIA     Florida   37
#
#    player_height  player_weight                   country draft_year  ...  \
# 0         205.74       102.0582  United States of America       1985  ...
# 1         205.74       102.0582  United States of America       1985  ...
# 2         205.74       102.0582  United States of America       1985  ...
# 3         205.74       102.0582  United States of America       1985  ...
# 4         205.74       102.0582  United States of America       1985  ...
#
#   net_rating oreb_pct  dreb_pct  usg_pct  ts_pct  ast_pct    mvp  position  \
# 0       -8.0    0.100     0.207    0.119   0.523    0.045  False        PF
# 1       -7.2    0.090     0.196    0.118   0.496    0.074  False        PF
# 2       -5.6    0.097     0.179    0.148   0.441    0.043  False        PF
# 3        8.1    0.089     0.179    0.111   0.482    0.058  False        PF
# 4        3.3    0.089     0.171    0.141   0.492    0.050  False        PF
#
#    experience  season_result
# 0          12  No postseason
# 1          13  No postseason
# 2          14  No postseason
# 3          15       Champion
# 4          16       Playoffs
#
# [5 rows x 26 columns]

# %%
# Create a subset which contains only the nuerical values
sub = df[['net_rating','pts', 'reb', 'ast', 'oreb_pct', 'dreb_pct', 'ts_pct', 'ast_pct', 'usg_pct']]

# %%
sub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9803 entries, 0 to 12841
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   net_rating  9803 non-null   float64
#  1   pts         9803 non-null   float64
#  2   reb         9803 non-null   float64
#  3   ast         9803 non-null   float64
#  4   oreb_pct    9803 non-null   float64
#  5   dreb_pct    9803 non-null   float64
#  6   ts_pct      9803 non-null   float64
#  7   ast_pct     9803 non-null   float64
#  8   usg_pct     9803 non-null   float64
# dtypes: float64(9)
# memory usage: 765.9 KB

# %%
num_cl = range(1, 10) # Defines the range of potential clusters in the data.
kmeans = [KMeans(n_clusters=i) for i in num_cl] # Defines k-means clusters in the range assigned above.

# %%
score = [kmeans[i].fit(sub).score(sub) for i in range(len(kmeans))] # Creates a score that represents 
# a rate of variation for the given cluster option.

score
# Out:
# C:\Users\logan\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\logan\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\logan\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\logan\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\logan\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\logan\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\logan\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\logan\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\logan\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# [-797289.8605980641,
#  -504919.3535092746,
#  -349784.030733495,
#  -292477.9520317975,
#  -246505.9902679428,
#  -219668.69169669788,
#  -200657.27127622045,
#  -183926.12030506437,
#  -168692.99562277997]

# %%
# Plot the elbow curve using PyLab.

pl.plot(num_cl,score)
pl.xlabel('Number of Clusters')
pl.ylabel('Score')
pl.title('Elbow Curve')
pl.show()

# %% [markdown]
# ### Not a  great looking curve, so we'll try 3

# %%
# Create the k-means object.

kmeans = KMeans(n_clusters = 5)

# %%
sub['clusters'] = kmeans.fit_predict(sub)
# Out:
# C:\Users\logan\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\logan\AppData\Local\Temp\ipykernel_10612\3683309691.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub['clusters'] = kmeans.fit_predict(sub)

# %%
sub.head()
# Out:
#    net_rating  pts  reb  ast  oreb_pct  dreb_pct  ts_pct  ast_pct  usg_pct  \
# 0        -8.0  7.2  7.9  0.8     0.100     0.207   0.523    0.045    0.119
# 1        -7.2  7.3  8.1  1.5     0.090     0.196   0.496    0.074    0.118
# 2        -5.6  4.9  4.6  0.5     0.097     0.179   0.441    0.043    0.148
# 3         8.1  5.0  5.9  1.0     0.089     0.179   0.482    0.058    0.111
# 4         3.3  4.5  3.8  0.5     0.089     0.171   0.492    0.050    0.141
#
#    clusters
# 0         1
# 1         1
# 2         1
# 3         2
# 4         4

# %%
sub['clusters'].value_counts()
# Out:
# clusters
# 4    2878
# 2    2056
# 3    1840
# 1    1798
# 0    1231
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,8))
ax = sns.scatterplot(x=sub['pts'], y=sub['net_rating'], hue=kmeans.labels_, s=100) 
# Here, you're subsetting `X` for the x and y arguments to avoid using their labels. 
# `hue` takes the value of the attribute `kmeans.labels_`, which is the result of running the k-means algorithm.
# `s` represents the size of the points you want to see in the plot.

ax.grid(False) # This removes the grid from the background.
plt.xlabel('Points per game') # Label x-axis.
plt.ylabel('Net Rating') # Label y-axis.
plt.show()
# Out:
# C:\Users\logan\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\logan\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\logan\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
plt.figure(figsize=(12,8))
ax = sns.scatterplot(x=sub['usg_pct'], y=sub['net_rating'], hue=kmeans.labels_, s=100) 
# Here, you're subsetting `X` for the x and y arguments to avoid using their labels. 
# `hue` takes the value of the attribute `kmeans.labels_`, which is the result of running the k-means algorithm.
# `s` represents the size of the points you want to see in the plot.

ax.grid(False) # This removes the grid from the background.
plt.xlabel('Usage Percentage') # Label x-axis.
plt.ylabel('Net Rating') # Label y-axis.
plt.show()
# Out:
# C:\Users\logan\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\logan\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\logan\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# ### These are okay... but let's just try 4

# %%
# Create the k-means object.

kmeans = KMeans(n_clusters = 4)

# %%
sub['clusters'] = kmeans.fit_predict(sub)

# %%
sub['clusters'].value_counts()

# %%
plt.figure(figsize=(12,8))
ax = sns.scatterplot(x=sub['pts'], y=sub['net_rating'], hue=kmeans.labels_, s=100) 
# Here, you're subsetting `X` for the x and y arguments to avoid using their labels. 
# `hue` takes the value of the attribute `kmeans.labels_`, which is the result of running the k-means algorithm.
# `s` represents the size of the points you want to see in the plot.

ax.grid(False) # This removes the grid from the background.
plt.xlabel('Points per game') # Label x-axis.
plt.ylabel('Net Rating') # Label y-axis.
plt.show()

# %%
plt.figure(figsize=(12,8))
ax = sns.scatterplot(x=sub['usg_pct'], y=sub['net_rating'], hue=kmeans.labels_, s=100) 
# Here, you're subsetting `X` for the x and y arguments to avoid using their labels. 
# `hue` takes the value of the attribute `kmeans.labels_`, which is the result of running the k-means algorithm.
# `s` represents the size of the points you want to see in the plot.

ax.grid(False) # This removes the grid from the background.
plt.xlabel('Usage Percentage') # Label x-axis.
plt.ylabel('Net Rating') # Label y-axis.
plt.show()

# %%
plt.figure(figsize=(12,8))
ax = sns.scatterplot(x=sub['ts_pct'], y=sub['net_rating'], hue=kmeans.labels_, s=100) 
# Here, you're subsetting `X` for the x and y arguments to avoid using their labels. 
# `hue` takes the value of the attribute `kmeans.labels_`, which is the result of running the k-means algorithm.
# `s` represents the size of the points you want to see in the plot.

ax.grid(False) # This removes the grid from the background.
plt.xlabel('True Shooting Percentage') # Label x-axis.
plt.ylabel('Net Rating') # Label y-axis.
plt.show()

# %% [markdown]
# ### I prefer 3 clusters

# %%
# Create the k-means object.

kmeans = KMeans(n_clusters = 3)

# %%
sub['clusters'] = kmeans.fit_predict(sub)

# %%
sub['clusters'].value_counts()

# %%
plt.figure(figsize=(12,8))
ax = sns.scatterplot(x=sub['ts_pct'], y=sub['net_rating'], hue=kmeans.labels_, s=100) 
# Here, you're subsetting `X` for the x and y arguments to avoid using their labels. 
# `hue` takes the value of the attribute `kmeans.labels_`, which is the result of running the k-means algorithm.
# `s` represents the size of the points you want to see in the plot.

ax.grid(False) # This removes the grid from the background.
plt.xlabel('True Shooting Percentage') # Label x-axis.
plt.ylabel('Net Rating') # Label y-axis.
plt.show()

# %%
plt.figure(figsize=(12,8))
ax = sns.scatterplot(x=sub['pts'], y=sub['net_rating'], hue=kmeans.labels_, s=100) 
# Here, you're subsetting `X` for the x and y arguments to avoid using their labels. 
# `hue` takes the value of the attribute `kmeans.labels_`, which is the result of running the k-means algorithm.
# `s` represents the size of the points you want to see in the plot.

ax.grid(False) # This removes the grid from the background.
plt.xlabel('Points per game') # Label x-axis.
plt.ylabel('Net Rating') # Label y-axis.
plt.show()

# %% [markdown]
# ### the clustering of the scatterplot above makes more sense, in that dark is negative role type player, purple is positive role type player, and pink is more of a star player.

# %%
sub.loc[sub['clusters'] == 2, 'cluster'] = 'dark'
sub.loc[sub['clusters'] == 1, 'cluster'] = 'purple'
sub.loc[sub['clusters'] == 0, 'cluster'] = 'pink'

# %%
sub.groupby('cluster').agg({'net_rating':['mean', 'median'], 
                         'pts':['mean', 'median'], 
                         'usg_pct':['mean', 'median']})

# %%
#adding games played after to see if games played is different in the different groups since it messed up the charts
sub['gp'] = df['gp'].values

# %%
sub.groupby('cluster').agg({'net_rating':['mean', 'median'], 
                         'pts':['mean', 'median'], 
                         'usg_pct':['mean', 'median'],
                           'gp':['mean', 'median']})

# %% [markdown]
# ### Adding games played helped showcases that positive role players get to play more games than negative ones, while stars get the most

# %% [markdown]
# ### It could be useful to see the average number of each on a playoff team, championship team, etc.

# %%
df.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'stats cleaned.csv'))
sub.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'clusters.csv'))
